# %% [markdown]
# # Introduction to Model-Free Predictive Inference (DSO 621)
#
# This is a Jupyter notebook similar to those we will use in this class.
#
# At the beginning of the class, I will upload the real notebooks in this shared folder.
#
# ## Optional preparation material
#
# To learn more about Jupyter notebooks and Colab:
#
#    - https://colab.research.google.com/notebooks/intro.ipynb
#
#    - https://jupyter.org/
#
# There are a lot of free resources online to learn Python. Some that are particularly relevant are these:
#
#    - https://cs231n.github.io/python-numpy-tutorial/
#
#    - http://web.stanford.edu/class/cme193/fall_2019_2020_lecs.html

# %% [markdown]
# ## Dependencies
#
# Some of the notebooks in this course depend on the scikit-garden package. Unfortunately, the scikit-garden package available through the standard repositories (pip install scikit-garden) no longer works with newer versions of sklearn. Therefore, it is recommended to install scikit-garden by cloning directly from the GitHub repository:
# https://github.com/scikit-garden/scikit-garden

# %% [markdown]
# ## Simple demonstration
#
# Jupyter notebooks allow you to easily combine good looking text (and figures) with executable Python code.
#
# Here's an example.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# Here are some more interesting examples.

# %%
import numpy as np

n = 1000
x = np.random.normal(0, 1, n)
np.mean(x)
# Out:
# 0.01746030591330003

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(x)
plt.show()

# %%
y = 2*x + 3 + np.random.normal(0, 1, n)
plt.hist(y)
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(x.reshape((n,1)), y)
y_pred = regr.predict(x.reshape((n,1)))

plt.scatter(x,y, alpha=0.2)
plt.plot(x, y_pred, color='red')
plt.show()
